# %% [markdown]
# # Facial Emotion Recogination

# %% [markdown]
# reference : https://www.kaggle.com/aroraumang/facial-emotion-recogination-82-accuracy

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %% [markdown]
# Importing Dataset

# %%
train_dir = 'fer2013/modified/train/'
test_dir = 'fer2013/modified/test/'

row, col = 48, 48
classes = 3
emotion_labels = ['angry', 'happy', 'neutral']

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print('sum of train : ', sum(train_count.iloc[0]))
print(test_count)
print('sum of test : ', sum(test_count.iloc[0]))
# Out:
#        angry  happy  neutral
# train   3860   6722     4648
# sum of train :  15230
#       angry  happy  neutral
# test    907   1621     1101
# sum of test :  3629

# %% [markdown]
# Plot of number of images in training set

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plot of number of images in test set

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    print(np.asarray(img).shape)
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %% [markdown]
# Creating Training and Test sets

# %%
train_datagen = ImageDataGenerator(rescale=(1./255 - 0.5)*2.0,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=8, # 64,
                                                target_size=(48,48),
                                                shuffle=False,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=(1./255 - 0.5)*2.0)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=8, # 64,
                                                target_size=(48,48),
                                                shuffle=False,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 15230 images belonging to 3 classes.
# Found 3629 images belonging to 3 classes.

# %%
test_set

# %%
training_set.class_indices
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2}

# %% [markdown]
# Defining Model

# %%
def get_model(input_size, classes=3):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              31720448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 32,112,643
# Trainable params: 32,112,003
# Non-trainable params: 640
# _________________________________________________________________

# %%
#!pip install pydot
#!pip install graphviz
#!pip install pydotplus
#!pip install django-extensions
#!pip install pyparsing

# %%
plot_model(fernet, to_file='model_plot1_3.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Callbacks Function

# %%
chk_path = 'models_1_3/{epoch:02d}-{val_accuracy:.2f}.h5'
log_dir = "models_1_3/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1)
                             #mode='max', #'min',
                             #moniter='accuracy') # 'val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# Training Model

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 1903/1903 [==============================] - 1043s 547ms/step - loss: 4.4436 - accuracy: 0.4594 - val_loss: 2.7449 - val_accuracy: 0.6280
#
# Epoch 00001: val_accuracy improved from -inf to 0.62804, saving model to models_1_3\01-0.63.h5
# Epoch 2/60
# 1903/1903 [==============================] - 1012s 532ms/step - loss: 2.6182 - accuracy: 0.5662 - val_loss: 1.8278 - val_accuracy: 0.6496
#
# Epoch 00002: val_accuracy improved from 0.62804 to 0.64956, saving model to models_1_3\02-0.65.h5
# Epoch 3/60
# 1903/1903 [==============================] - 1017s 534ms/step - loss: 1.7791 - accuracy: 0.6071 - val_loss: 1.2702 - val_accuracy: 0.6854
#
# Epoch 00003: val_accuracy improved from 0.64956 to 0.68543, saving model to models_1_3\03-0.69.h5
# Epoch 4/60
# 1903/1903 [==============================] - 1012s 532ms/step - loss: 1.2741 - accuracy: 0.6447 - val_loss: 0.9663 - val_accuracy: 0.7141
#
# Epoch 00004: val_accuracy improved from 0.68543 to 0.71413, saving model to models_1_3\04-0.71.h5
# Epoch 5/60
# 1903/1903 [==============================] - 1005s 528ms/step - loss: 1.0078 - accuracy: 0.6729 - val_loss: 0.8176 - val_accuracy: 0.7362
#
# Epoch 00005: val_accuracy improved from 0.71413 to 0.73620, saving model to models_1_3\05-0.74.h5
# Epoch 6/60
# 1903/1903 [==============================] - 1014s 533ms/step - loss: 0.8776 - accuracy: 0.6988 - val_loss: 0.8088 - val_accuracy: 0.7130
#
# Epoch 00006: val_accuracy did not improve from 0.73620
# Epoch 7/60
# 1903/1903 [==============================] - 1016s 534ms/step - loss: 0.8093 - accuracy: 0.7021 - val_loss: 0.6699 - val_accuracy: 0.7660
#
# Epoch 00007: val_accuracy improved from 0.73620 to 0.76600, saving model to models_1_3\07-0.77.h5
# Epoch 8/60
# 1903/1903 [==============================] - 1019s 535ms/step - loss: 0.7579 - accuracy: 0.7226 - val_loss: 0.6925 - val_accuracy: 0.7403
#
# Epoch 00008: val_accuracy did not improve from 0.76600
# Epoch 9/60
# 1903/1903 [==============================] - 1011s 531ms/step - loss: 0.7259 - accuracy: 0.7337 - val_loss: 0.6469 - val_accuracy: 0.7674
#
# Epoch 00009: val_accuracy improved from 0.76600 to 0.76738, saving model to models_1_3\09-0.77.h5
# Epoch 10/60
# 1903/1903 [==============================] - 1018s 535ms/step - loss: 0.7095 - accuracy: 0.7428 - val_loss: 0.6460 - val_accuracy: 0.7630
#
# Epoch 00010: val_accuracy did not improve from 0.76738
# Epoch 11/60
# 1903/1903 [==============================] - 1016s 534ms/step - loss: 0.6862 - accuracy: 0.7532 - val_loss: 0.5797 - val_accuracy: 0.7958
#
# Epoch 00011: val_accuracy improved from 0.76738 to 0.79581, saving model to models_1_3\11-0.80.h5
# Epoch 12/60
# 1903/1903 [==============================] - 1012s 532ms/step - loss: 0.6661 - accuracy: 0.7564 - val_loss: 0.5756 - val_accuracy: 0.7966
#
# Epoch 00012: val_accuracy improved from 0.79581 to 0.79663, saving model to models_1_3\12-0.80.h5
# Epoch 13/60
# 1903/1903 [==============================] - 1007s 529ms/step - loss: 0.6583 - accuracy: 0.7617 - val_loss: 0.5621 - val_accuracy: 0.7975
#
# Epoch 00013: val_accuracy improved from 0.79663 to 0.79746, saving model to models_1_3\13-0.80.h5
# Epoch 14/60
# 1903/1903 [==============================] - 1005s 528ms/step - loss: 0.6364 - accuracy: 0.7711 - val_loss: 0.6694 - val_accuracy: 0.7481
#
# Epoch 00014: val_accuracy did not improve from 0.79746
# Epoch 15/60
# 1903/1903 [==============================] - 1030s 541ms/step - loss: 0.6306 - accuracy: 0.7699 - val_loss: 0.5541 - val_accuracy: 0.8055
#
# Epoch 00015: val_accuracy improved from 0.79746 to 0.80546, saving model to models_1_3\15-0.81.h5
# Epoch 16/60
# 1903/1903 [==============================] - 1005s 528ms/step - loss: 0.6125 - accuracy: 0.7748 - val_loss: 0.6037 - val_accuracy: 0.7781
#
# Epoch 00016: val_accuracy did not improve from 0.80546
# Epoch 17/60
# 1903/1903 [==============================] - 1009s 530ms/step - loss: 0.6100 - accuracy: 0.7829 - val_loss: 0.5504 - val_accuracy: 0.8016
#
# Epoch 00017: val_accuracy did not improve from 0.80546
# Epoch 18/60
# 1903/1903 [==============================] - 1011s 531ms/step - loss: 0.5969 - accuracy: 0.7897 - val_loss: 0.5470 - val_accuracy: 0.8060
#
# Epoch 00018: val_accuracy improved from 0.80546 to 0.80602, saving model to models_1_3\18-0.81.h5
# Epoch 19/60
# 1903/1903 [==============================] - 1007s 529ms/step - loss: 0.6057 - accuracy: 0.7797 - val_loss: 0.5750 - val_accuracy: 0.7936
#
# Epoch 00019: val_accuracy did not improve from 0.80602
# Epoch 20/60
# 1903/1903 [==============================] - 1006s 529ms/step - loss: 0.5713 - accuracy: 0.7999 - val_loss: 0.5178 - val_accuracy: 0.8157
#
# Epoch 00020: val_accuracy improved from 0.80602 to 0.81567, saving model to models_1_3\20-0.82.h5
# Epoch 21/60
# 1903/1903 [==============================] - 1013s 532ms/step - loss: 0.5742 - accuracy: 0.7941 - val_loss: 0.5393 - val_accuracy: 0.8184
#
# Epoch 00021: val_accuracy improved from 0.81567 to 0.81843, saving model to models_1_3\21-0.82.h5
# Epoch 22/60
# 1903/1903 [==============================] - 1016s 534ms/step - loss: 0.5610 - accuracy: 0.7992 - val_loss: 0.5307 - val_accuracy: 0.8126
#
# Epoch 00022: val_accuracy did not improve from 0.81843
# Epoch 23/60
# 1903/1903 [==============================] - 1015s 533ms/step - loss: 0.5712 - accuracy: 0.7972 - val_loss: 0.5123 - val_accuracy: 0.8193
#
# Epoch 00023: val_accuracy improved from 0.81843 to 0.81926, saving model to models_1_3\23-0.82.h5
# Epoch 24/60
# 1903/1903 [==============================] - 1014s 533ms/step - loss: 0.5526 - accuracy: 0.8094 - val_loss: 0.5183 - val_accuracy: 0.8182
#
# Epoch 00024: val_accuracy did not improve from 0.81926
# Epoch 25/60
# 1903/1903 [==============================] - 1016s 534ms/step - loss: 0.5500 - accuracy: 0.8034 - val_loss: 0.5305 - val_accuracy: 0.8091
#
# Epoch 00025: val_accuracy did not improve from 0.81926
# Epoch 26/60
# 1903/1903 [==============================] - 1059s 557ms/step - loss: 0.5439 - accuracy: 0.8037 - val_loss: 0.5235 - val_accuracy: 0.8201
#
# Epoch 00026: val_accuracy improved from 0.81926 to 0.82009, saving model to models_1_3\26-0.82.h5
# Epoch 27/60
# 1903/1903 [==============================] - 1009s 530ms/step - loss: 0.5363 - accuracy: 0.8129 - val_loss: 0.5213 - val_accuracy: 0.8231
#
# Epoch 00027: val_accuracy improved from 0.82009 to 0.82312, saving model to models_1_3\27-0.82.h5
# Epoch 28/60
# 1903/1903 [==============================] - 1021s 536ms/step - loss: 0.5419 - accuracy: 0.8127 - val_loss: 0.5519 - val_accuracy: 0.8226
#
# Epoch 00028: val_accuracy did not improve from 0.82312
# Epoch 29/60
# 1903/1903 [==============================] - 1015s 533ms/step - loss: 0.5247 - accuracy: 0.8160 - val_loss: 0.5160 - val_accuracy: 0.8284
#
# Epoch 00029: val_accuracy improved from 0.82312 to 0.82837, saving model to models_1_3\29-0.83.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 30/60
# 1903/1903 [==============================] - 1007s 529ms/step - loss: 0.4952 - accuracy: 0.8290 - val_loss: 0.4815 - val_accuracy: 0.8397
#
# Epoch 00030: val_accuracy improved from 0.82837 to 0.83968, saving model to models_1_3\30-0.84.h5
# Epoch 31/60
# 1903/1903 [==============================] - 1020s 536ms/step - loss: 0.4571 - accuracy: 0.8473 - val_loss: 0.4879 - val_accuracy: 0.8397
#
# Epoch 00031: val_accuracy did not improve from 0.83968
# Epoch 32/60
# 1903/1903 [==============================] - 1018s 535ms/step - loss: 0.4469 - accuracy: 0.8508 - val_loss: 0.4767 - val_accuracy: 0.8430
#
# Epoch 00032: val_accuracy improved from 0.83968 to 0.84299, saving model to models_1_3\32-0.84.h5
# Epoch 33/60
# 1903/1903 [==============================] - 1013s 533ms/step - loss: 0.4266 - accuracy: 0.8526 - val_loss: 0.4743 - val_accuracy: 0.8411
#
# Epoch 00033: val_accuracy did not improve from 0.84299
# Epoch 34/60
# 1903/1903 [==============================] - 1015s 534ms/step - loss: 0.4207 - accuracy: 0.8560 - val_loss: 0.4969 - val_accuracy: 0.8391
#
# Epoch 00034: val_accuracy did not improve from 0.84299
# Epoch 35/60
# 1903/1903 [==============================] - 1009s 530ms/step - loss: 0.4213 - accuracy: 0.8605 - val_loss: 0.4828 - val_accuracy: 0.8427
#
# Epoch 00035: val_accuracy did not improve from 0.84299
# Epoch 36/60
# 1903/1903 [==============================] - 1008s 530ms/step - loss: 0.4180 - accuracy: 0.8592 - val_loss: 0.4580 - val_accuracy: 0.8469
#
# Epoch 00036: val_accuracy improved from 0.84299 to 0.84685, saving model to models_1_3\36-0.85.h5
# Epoch 37/60
# 1903/1903 [==============================] - 1002s 527ms/step - loss: 0.4016 - accuracy: 0.8659 - val_loss: 0.4690 - val_accuracy: 0.8452
#
# Epoch 00037: val_accuracy did not improve from 0.84685
# Epoch 38/60
# 1903/1903 [==============================] - 1000s 526ms/step - loss: 0.4102 - accuracy: 0.8562 - val_loss: 0.4842 - val_accuracy: 0.8427
#
# Epoch 00038: val_accuracy did not improve from 0.84685
# Epoch 39/60
# 1903/1903 [==============================] - 1004s 528ms/step - loss: 0.4108 - accuracy: 0.8630 - val_loss: 0.4607 - val_accuracy: 0.8485
#
# Epoch 00039: val_accuracy improved from 0.84685 to 0.84851, saving model to models_1_3\39-0.85.h5
# Epoch 40/60
# 1903/1903 [==============================] - 998s 524ms/step - loss: 0.3878 - accuracy: 0.8710 - val_loss: 0.4681 - val_accuracy: 0.8449
#
# Epoch 00040: val_accuracy did not improve from 0.84851
# Epoch 41/60
# 1903/1903 [==============================] - 1000s 526ms/step - loss: 0.3850 - accuracy: 0.8747 - val_loss: 0.4767 - val_accuracy: 0.8449
#
# Epoch 00041: val_accuracy did not improve from 0.84851
# Epoch 42/60
# 1903/1903 [==============================] - 1001s 526ms/step - loss: 0.3984 - accuracy: 0.8673 - val_loss: 0.4780 - val_accuracy: 0.8449
#
# Epoch 00042: val_accuracy did not improve from 0.84851
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 43/60
# 1903/1903 [==============================] - 1008s 530ms/step - loss: 0.3816 - accuracy: 0.8731 - val_loss: 0.4734 - val_accuracy: 0.8466
#
# Epoch 00043: val_accuracy did not improve from 0.84851
# Epoch 44/60
# 1903/1903 [==============================] - 999s 525ms/step - loss: 0.3679 - accuracy: 0.8733 - val_loss: 0.4717 - val_accuracy: 0.8474
#
# Epoch 00044: val_accuracy did not improve from 0.84851
# Epoch 45/60
# 1903/1903 [==============================] - 999s 525ms/step - loss: 0.3709 - accuracy: 0.8761 - val_loss: 0.4682 - val_accuracy: 0.8488
#
# Epoch 00045: val_accuracy improved from 0.84851 to 0.84879, saving model to models_1_3\45-0.85.h5
# Epoch 46/60
# 1903/1903 [==============================] - 998s 524ms/step - loss: 0.3700 - accuracy: 0.8743 - val_loss: 0.4712 - val_accuracy: 0.8504
#
# Epoch 00046: val_accuracy improved from 0.84879 to 0.85044, saving model to models_1_3\46-0.85.h5
# Epoch 47/60
# 1903/1903 [==============================] - 997s 524ms/step - loss: 0.3685 - accuracy: 0.8789 - val_loss: 0.4724 - val_accuracy: 0.8474
#
# Epoch 00047: val_accuracy did not improve from 0.85044
# Epoch 48/60
# 1903/1903 [==============================] - 1004s 528ms/step - loss: 0.3714 - accuracy: 0.8733 - val_loss: 0.4713 - val_accuracy: 0.8458
#
# Epoch 00048: val_accuracy did not improve from 0.85044
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 49/60
# 1903/1903 [==============================] - 989s 520ms/step - loss: 0.3608 - accuracy: 0.8796 - val_loss: 0.4698 - val_accuracy: 0.8471
#
# Epoch 00049: val_accuracy did not improve from 0.85044
# Epoch 50/60
# 1903/1903 [==============================] - 1011s 531ms/step - loss: 0.3613 - accuracy: 0.8798 - val_loss: 0.4732 - val_accuracy: 0.8482
#
# Epoch 00050: val_accuracy did not improve from 0.85044
# Epoch 51/60
# 1903/1903 [==============================] - 994s 522ms/step - loss: 0.3545 - accuracy: 0.8812 - val_loss: 0.4682 - val_accuracy: 0.8474
#
# Epoch 00051: val_accuracy did not improve from 0.85044
# Epoch 52/60
# 1903/1903 [==============================] - 995s 523ms/step - loss: 0.3543 - accuracy: 0.8811 - val_loss: 0.4662 - val_accuracy: 0.8477
#
# Epoch 00052: val_accuracy did not improve from 0.85044
# Epoch 53/60
# 1903/1903 [==============================] - 995s 523ms/step - loss: 0.3580 - accuracy: 0.8818 - val_loss: 0.4694 - val_accuracy: 0.8480
#
# Epoch 00053: val_accuracy did not improve from 0.85044
# Epoch 54/60
# 1903/1903 [==============================] - 1013s 532ms/step - loss: 0.3643 - accuracy: 0.8807 - val_loss: 0.4720 - val_accuracy: 0.8480
#
# Epoch 00054: val_accuracy did not improve from 0.85044
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# Epoch 55/60
# 1903/1903 [==============================] - 996s 523ms/step - loss: 0.3600 - accuracy: 0.8825 - val_loss: 0.4719 - val_accuracy: 0.8482
#
# Epoch 00055: val_accuracy did not improve from 0.85044
# Epoch 56/60
# 1903/1903 [==============================] - 993s 522ms/step - loss: 0.3607 - accuracy: 0.8782 - val_loss: 0.4729 - val_accuracy: 0.8480
#
# Epoch 00056: val_accuracy did not improve from 0.85044
# Epoch 57/60
# 1903/1903 [==============================] - 996s 523ms/step - loss: 0.3656 - accuracy: 0.8813 - val_loss: 0.4724 - val_accuracy: 0.8485
#
# Epoch 00057: val_accuracy did not improve from 0.85044
# Epoch 58/60
# 1903/1903 [==============================] - 1023s 538ms/step - loss: 0.3489 - accuracy: 0.8817 - val_loss: 0.4712 - val_accuracy: 0.8485
#
# Epoch 00058: val_accuracy did not improve from 0.85044
# Epoch 59/60
# 1903/1903 [==============================] - 995s 523ms/step - loss: 0.3542 - accuracy: 0.8805 - val_loss: 0.4704 - val_accuracy: 0.8477
#
# Epoch 00059: val_accuracy did not improve from 0.85044
# Epoch 60/60
# 1903/1903 [==============================] - 995s 523ms/step - loss: 0.3620 - accuracy: 0.8807 - val_loss: 0.4707 - val_accuracy: 0.8477
#
# Epoch 00060: val_accuracy did not improve from 0.85044
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.

# %% [markdown]
# Loss and Accuracy plot

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Model Evaluation

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 1904/1904 [==============================] - 138s 73ms/step - loss: 0.2924 - accuracy: 0.9098
# 454/454 [==============================] - 31s 69ms/step - loss: 0.4702 - accuracy: 0.8479
# final train accuracy = 90.98 , validation accuracy = 84.79

# %%
fernet.save_weights('fernet_bestweight_1_3.h5')

# %%
fernet.save('fernet_best_1_3.h5')

# %% [markdown]
# Confusion Matrix and Classification on training set

# %%
plt.figure(figsize=(10, 10))
for images, labels in training_set:
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    print(labels[i])
    plt.title(emotion_labels[labels[i]])
    plt.axis("off")

# %%
fernet = load_model('fernet_best_1_3.h5')
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
print(y_pred)

class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)

# %% [markdown]
# Confusion Matrix and Classification on test set

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

#from sklearn.metrics import classification_report, confusion_matrix
cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[205 393 309]
#  [368 725 528]
#  [251 473 377]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.25      0.23      0.24       907
#        happy       0.46      0.45      0.45      1621
#      neutral       0.31      0.34      0.33      1101
#
#     accuracy                           0.36      3629
#    macro avg       0.34      0.34      0.34      3629
# weighted avg       0.36      0.36      0.36      3629

# %% [markdown]
# # 단일 사진 결과 확인

# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import cv2
import numpy as np
import sys
import time
#from google.colab.patches import cv2_imshow
 
# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
emotion_model_path = 'fernet_best_1_3.h5'
img_path =  "angry.jpg" # sys.argv[1]
 
# hyper-parameters for bounding boxes shape
# loading models
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ['angry', 'happy', 'neutral'] # , 'sad']
            
 
# reading the frame
orig_frame = cv2.imread(img_path)
#print(img_path)
#print(orig_frame)
frame = cv2.imread(img_path,0)
#print(frame)
faces = face_detection.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=5,minSize=(30,30),flags=cv2.CASCADE_SCALE_IMAGE)
 
if len(faces) > 0:
    print(faces)
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))[0]
    (fX, fY, fW, fH) = faces
    roi = frame[fY:fY + fH, fX:fX + fW]
    roi = cv2.resize(roi, (48, 48))
    roi = roi.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi, axis=0)
    preds = emotion_classifier.predict(roi)[0]
    emotion_probability = np.max(preds)
    label = EMOTIONS[preds.argmax()]
    cv2.putText(orig_frame, label, (fX, fY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
    cv2.rectangle(orig_frame, (fX, fY), (fX + fW, fY + fH),(0, 0, 255), 2)
 
cv2.imshow('test_face', orig_frame)
#cv2_imshow(orig_frame)
cv2.imwrite('test_output/'+img_path.split('/')[-1],orig_frame)
if (cv2.waitKey(0) and 0xFF == ord('q')):
    sys.exit("Thanks")
cv2.destroyAllWindows()
# Out:
# [[182 146 471 471]]

# %%
roi.shape
# Out:
# (1, 48, 48, 1)

# %% [markdown]
# # 실시간 영상을 통한 결과 확인

# %%
from statistics import mode

import cv2
from keras.models import load_model
import numpy as np

from utils.datasets import get_labels
from utils.inference import detect_faces
from utils.inference import draw_text
from utils.inference import draw_bounding_box
from utils.inference import apply_offsets
from utils.inference import load_detection_model
from utils.preprocessor import preprocess_input

# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
#emotion_model_path = 'ferNet.h5'
emotion_model_path = 'fernet_best_1_3.h5'
emotion_labels = ['angry', 'happy', 'neutral'] # , 'sad']

# hyper-parameters for bounding boxes shape
frame_window = 10
emotion_offsets = (20, 40)

# loading models
face_detection = load_detection_model(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)

# getting input model shapes for inference
emotion_target_size = emotion_classifier.input_shape[1:3]

# starting lists for calculating modes
emotion_window = []

# %%
face_detection
# Out:
# <CascadeClassifier 0000027F4980BF70>

# %%
emotion_labels
# Out:
# ['angry', 'happy', 'neutral']

# %%
from keras.preprocessing.image import img_to_array

# starting video streaming
cv2.namedWindow('window_frame')
video_capture = cv2.VideoCapture(0)
while True:
    bgr_image = video_capture.read()[1]
    gray_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2GRAY)
    rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
    faces = detect_faces(face_detection, gray_image)
    
    for face_coordinates in faces:

        x1, x2, y1, y2 = apply_offsets(face_coordinates, emotion_offsets)
        gray_face = gray_image[y1:y2, x1:x2]
        try:
            gray_face = cv2.resize(gray_face, (emotion_target_size))
        except:
            continue

        gray_face = preprocess_input(gray_face, True)
        gray_face = np.expand_dims(gray_face, 0)
        gray_face = np.expand_dims(gray_face, -1)
        emotion_prediction = emotion_classifier.predict(gray_face)
        emotion_probability = np.max(emotion_prediction)
        emotion_label_arg = np.argmax(emotion_prediction)
        emotion_text = emotion_labels[emotion_label_arg]
        emotion_window.append(emotion_text)

        if len(emotion_window) > frame_window:
            emotion_window.pop(0)
        try:
            emotion_mode = mode(emotion_window)
        except:
            continue

        if emotion_text == 'angry':
            color = emotion_probability * np.asarray((255, 0, 0))
        elif emotion_text == 'happy':
            color = emotion_probability * np.asarray((0, 0, 255))
        elif emotion_text == 'neutral':
            color = emotion_probability * np.asarray((255, 255, 0))
        elif emotion_text == 'sad':
            color = emotion_probability * np.asarray((0, 255, 255))
        else:
            color = emotion_probability * np.asarray((0, 255, 0))

        color = color.astype(int)
        color = color.tolist()

        draw_bounding_box(face_coordinates, rgb_image, color)
        draw_text(face_coordinates, rgb_image, emotion_mode,
                  color, 0, -45, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[0])+' : '+str(round(emotion_prediction[0][0],2)),
                  [0, 99, 99], 250, 10, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[1])+' : '+str(round(emotion_prediction[0][1],2)),
                  [99, 0, 99], 250, 60, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[2])+' : '+str(round(emotion_prediction[0][2],2)),
                  [0, 99, 0], 250, 110, 1, 1)
        #draw_text(face_coordinates, rgb_image, str(emotion_labels[3])+' : '+str(round(emotion_prediction[0][3],2)),
        #          [0, 0, 0], 250, 160, 1, 1)
        
        
        
    bgr_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2BGR)
    cv2.imshow('window_frame', bgr_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()

# %%
emotion_prediction
# Out:
# array([[9.9998462e-01, 1.4865484e-05, 4.1744153e-07]], dtype=float32)
