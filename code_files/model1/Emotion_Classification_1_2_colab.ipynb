# %% [markdown]
# # Facial Emotion Recogination

# %% [markdown]
# reference : https://www.kaggle.com/aroraumang/facial-emotion-recogination-82-accuracy

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/mnt')
# Out:
# Drive already mounted at /content/mnt; to attempt to forcibly remount, call drive.mount("/content/mnt", force_remount=True).

# %%
os.chdir('/content/mnt/MyDrive/GraduationProject/Emotion_Classification/')

# %%
os.getcwd()
# Out:
# '/content/mnt/MyDrive/GraduationProject/Emotion_Classification'

# %%
# !ls
# Out:
#  11.jpg					    model_best_0_5.h5
#  22.jpg					    model_best_1_2.h5
#  33.jpg					    model_bestweight_0_1.h5
#  44.jpg					    model_bestweight_0_2.h5
#  angry.jpg				    model_bestweight_0_3.h5
#  checkpoint				    model_bestweight_0_4.h5
#  Emotion_Classification_0_1.ipynb	    model_bestweight_0_5.h5
# 'Emotion_Classification_0_2 (1).ipynb'	    model_bestweight_1_2.h5
#  Emotion_Classification_0_2.ipynb	    model_plot_0_2.png
#  Emotion_Classification_0_3.ipynb	    models
#  Emotion_Classification_0_4.ipynb	    models_0
#  Emotion_Classification_0_5.ipynb	    models_0_1
#  Emotion_Classification_1_1.ipynb	    models_0_2
# 'Emotion_Classification_1_2 (1).ipynb'	   'models_0_2(1)'
#  Emotion_Classification_1_2_colab.ipynb     models_0_3
#  Emotion_Classification_1_2.ipynb	    models_0_4
#  Emotion_Classification_1_3.ipynb	    models_0_5
#  Emotion_Classification_2_0.ipynb	    models_1_1
#  Emotion_Classification.ipynb		    models_1_2
#  Emotion_Classification_Model_Summary.txt  'models_1_2(1)'
#  fer2013				    models_1_3
#  fernet.png				    models_2_0
#  ggg.jpg				    real_time_video.py
#  haarcascade_files			    test.csv
#  model_best_0_1.h5			    train.csv
#  model_best_0_2.h5			    training.log
#  model_best_0_3.h5			    utils
#  model_best_0_4.h5

# %% [markdown]
# Importing Dataset

# %%
train_dir = 'fer2013/modified/train2/'
test_dir = 'fer2013/modified/test2/'

row, col = 48, 48
classes = 3
emotion_labels = ['angry', 'happy', 'neutral']

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print('sum of train : ', sum(train_count.iloc[0]))
print(test_count)
print('sum of test : ', sum(test_count.iloc[0]))
# Out:
#        angry  neutral  happy
# train   3860     4649   6724
# sum of train :  15233
#       angry  neutral  happy
# test    907     1101   1621
# sum of test :  3629

# %% [markdown]
# Plot of number of images in training set

# %%
train_count.transpose().plot(kind='bar')

# %% [markdown]
# Plot of number of images in test set

# %%
test_count.transpose().plot(kind='bar')

# %%
plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    print(np.asarray(img).shape)
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %% [markdown]
# Creating Training and Test sets

# %%
train_datagen = ImageDataGenerator(rescale=(1./255 - 0.5)*2.0,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size= 64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=(1./255 - 0.5)*2.0)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size= 64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 15233 images belonging to 3 classes.
# Found 3629 images belonging to 3 classes.

# %%
test_set

# %%
training_set.class_indices
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2}

# %% [markdown]
# Defining Model

# %%
def get_model(input_size, classes=3):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              31720448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 32,112,643
# Trainable params: 32,112,003
# Non-trainable params: 640
# _________________________________________________________________

# %%
#!pip install pydot
#!pip install graphviz
#!pip install pydotplus
#!pip install django-extensions
#!pip install pyparsing

# %%
# plot_model(fernet, to_file='model_1_2.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Callbacks Function

# %%
chk_path = 'models_1_2/{epoch:02d}-{val_accuracy:.2f}.h5'
log_dir = "models_1_2/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             monitor='val_loss',
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# Training Model

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 238/238 [==============================] - 4437s 19s/step - loss: 4.7267 - accuracy: 0.4345 - val_loss: 3.3402 - val_accuracy: 0.5806
#
# Epoch 00001: val_loss improved from inf to 3.34016, saving model to models_1_2/01-0.58.h5
# Epoch 2/60
# 238/238 [==============================] - 619s 3s/step - loss: 3.3515 - accuracy: 0.5327 - val_loss: 3.0459 - val_accuracy: 0.5974
#
# Epoch 00002: val_loss improved from 3.34016 to 3.04594, saving model to models_1_2/02-0.60.h5
# Epoch 3/60
# 238/238 [==============================] - 619s 3s/step - loss: 3.0449 - accuracy: 0.5697 - val_loss: 2.7379 - val_accuracy: 0.6281
#
# Epoch 00003: val_loss improved from 3.04594 to 2.73792, saving model to models_1_2/03-0.63.h5
# Epoch 4/60
# 238/238 [==============================] - 619s 3s/step - loss: 2.7688 - accuracy: 0.5802 - val_loss: 2.4523 - val_accuracy: 0.6646
#
# Epoch 00004: val_loss improved from 2.73792 to 2.45229, saving model to models_1_2/04-0.66.h5
# Epoch 5/60
# 238/238 [==============================] - 619s 3s/step - loss: 2.4869 - accuracy: 0.6064 - val_loss: 2.1993 - val_accuracy: 0.6719
#
# Epoch 00005: val_loss improved from 2.45229 to 2.19934, saving model to models_1_2/05-0.67.h5
# Epoch 6/60
# 238/238 [==============================] - 619s 3s/step - loss: 2.2089 - accuracy: 0.6367 - val_loss: 1.9586 - val_accuracy: 0.6989
#
# Epoch 00006: val_loss improved from 2.19934 to 1.95858, saving model to models_1_2/06-0.70.h5
# Epoch 7/60
# 238/238 [==============================] - 618s 3s/step - loss: 1.9737 - accuracy: 0.6553 - val_loss: 1.7307 - val_accuracy: 0.7112
#
# Epoch 00007: val_loss improved from 1.95858 to 1.73067, saving model to models_1_2/07-0.71.h5
# Epoch 8/60
# 238/238 [==============================] - 619s 3s/step - loss: 1.7633 - accuracy: 0.6798 - val_loss: 1.5842 - val_accuracy: 0.7274
#
# Epoch 00008: val_loss improved from 1.73067 to 1.58422, saving model to models_1_2/08-0.73.h5
# Epoch 9/60
# 238/238 [==============================] - 620s 3s/step - loss: 1.5944 - accuracy: 0.6895 - val_loss: 1.3987 - val_accuracy: 0.7296
#
# Epoch 00009: val_loss improved from 1.58422 to 1.39873, saving model to models_1_2/09-0.73.h5
# Epoch 10/60
# 238/238 [==============================] - 622s 3s/step - loss: 1.4582 - accuracy: 0.7003 - val_loss: 1.2549 - val_accuracy: 0.7626
#
# Epoch 00010: val_loss improved from 1.39873 to 1.25487, saving model to models_1_2/10-0.76.h5
# Epoch 11/60
# 238/238 [==============================] - 623s 3s/step - loss: 1.3433 - accuracy: 0.7067 - val_loss: 1.2064 - val_accuracy: 0.7511
#
# Epoch 00011: val_loss improved from 1.25487 to 1.20644, saving model to models_1_2/11-0.75.h5
# Epoch 12/60
# 238/238 [==============================] - 627s 3s/step - loss: 1.2374 - accuracy: 0.7207 - val_loss: 1.1005 - val_accuracy: 0.7670
#
# Epoch 00012: val_loss improved from 1.20644 to 1.10049, saving model to models_1_2/12-0.77.h5
# Epoch 13/60
# 238/238 [==============================] - 622s 3s/step - loss: 1.1399 - accuracy: 0.7316 - val_loss: 1.0120 - val_accuracy: 0.7782
#
# Epoch 00013: val_loss improved from 1.10049 to 1.01197, saving model to models_1_2/13-0.78.h5
# Epoch 14/60
# 238/238 [==============================] - 624s 3s/step - loss: 1.0720 - accuracy: 0.7305 - val_loss: 0.9389 - val_accuracy: 0.7829
#
# Epoch 00014: val_loss improved from 1.01197 to 0.93886, saving model to models_1_2/14-0.78.h5
# Epoch 15/60
# 238/238 [==============================] - 623s 3s/step - loss: 1.0009 - accuracy: 0.7448 - val_loss: 0.9398 - val_accuracy: 0.7553
#
# Epoch 00015: val_loss did not improve from 0.93886
# Epoch 16/60
# 238/238 [==============================] - 623s 3s/step - loss: 0.9305 - accuracy: 0.7574 - val_loss: 0.8166 - val_accuracy: 0.7952
#
# Epoch 00016: val_loss improved from 0.93886 to 0.81661, saving model to models_1_2/16-0.80.h5
# Epoch 17/60
# 238/238 [==============================] - 622s 3s/step - loss: 0.8671 - accuracy: 0.7704 - val_loss: 0.7858 - val_accuracy: 0.7969
#
# Epoch 00017: val_loss improved from 0.81661 to 0.78579, saving model to models_1_2/17-0.80.h5
# Epoch 18/60
# 238/238 [==============================] - 630s 3s/step - loss: 0.8209 - accuracy: 0.7765 - val_loss: 0.7596 - val_accuracy: 0.7941
#
# Epoch 00018: val_loss improved from 0.78579 to 0.75956, saving model to models_1_2/18-0.79.h5
# Epoch 19/60
# 238/238 [==============================] - 624s 3s/step - loss: 0.7879 - accuracy: 0.7765 - val_loss: 0.7444 - val_accuracy: 0.7905
#
# Epoch 00019: val_loss improved from 0.75956 to 0.74435, saving model to models_1_2/19-0.79.h5
# Epoch 20/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.7562 - accuracy: 0.7813 - val_loss: 0.7612 - val_accuracy: 0.7712
#
# Epoch 00020: val_loss did not improve from 0.74435
# Epoch 21/60
# 238/238 [==============================] - 628s 3s/step - loss: 0.7260 - accuracy: 0.7841 - val_loss: 0.6567 - val_accuracy: 0.8122
#
# Epoch 00021: val_loss improved from 0.74435 to 0.65670, saving model to models_1_2/21-0.81.h5
# Epoch 22/60
# 238/238 [==============================] - 627s 3s/step - loss: 0.7043 - accuracy: 0.7935 - val_loss: 0.6934 - val_accuracy: 0.7899
#
# Epoch 00022: val_loss did not improve from 0.65670
# Epoch 23/60
# 238/238 [==============================] - 628s 3s/step - loss: 0.6849 - accuracy: 0.7950 - val_loss: 0.6192 - val_accuracy: 0.8178
#
# Epoch 00023: val_loss improved from 0.65670 to 0.61925, saving model to models_1_2/23-0.82.h5
# Epoch 24/60
# 238/238 [==============================] - 627s 3s/step - loss: 0.6645 - accuracy: 0.7946 - val_loss: 0.6122 - val_accuracy: 0.8158
#
# Epoch 00024: val_loss improved from 0.61925 to 0.61224, saving model to models_1_2/24-0.82.h5
# Epoch 25/60
# 238/238 [==============================] - 624s 3s/step - loss: 0.6296 - accuracy: 0.8059 - val_loss: 0.6133 - val_accuracy: 0.8153
#
# Epoch 00025: val_loss did not improve from 0.61224
# Epoch 26/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.6154 - accuracy: 0.8057 - val_loss: 0.5890 - val_accuracy: 0.8192
#
# Epoch 00026: val_loss improved from 0.61224 to 0.58901, saving model to models_1_2/26-0.82.h5
# Epoch 27/60
# 238/238 [==============================] - 631s 3s/step - loss: 0.5884 - accuracy: 0.8157 - val_loss: 0.6229 - val_accuracy: 0.8052
#
# Epoch 00027: val_loss did not improve from 0.58901
# Epoch 28/60
# 238/238 [==============================] - 624s 3s/step - loss: 0.5660 - accuracy: 0.8215 - val_loss: 0.5794 - val_accuracy: 0.8220
#
# Epoch 00028: val_loss improved from 0.58901 to 0.57943, saving model to models_1_2/28-0.82.h5
# Epoch 29/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.5555 - accuracy: 0.8271 - val_loss: 0.5707 - val_accuracy: 0.8167
#
# Epoch 00029: val_loss improved from 0.57943 to 0.57070, saving model to models_1_2/29-0.82.h5
# Epoch 30/60
# 238/238 [==============================] - 629s 3s/step - loss: 0.5444 - accuracy: 0.8278 - val_loss: 0.5672 - val_accuracy: 0.8281
#
# Epoch 00030: val_loss improved from 0.57070 to 0.56724, saving model to models_1_2/30-0.83.h5
# Epoch 31/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.5480 - accuracy: 0.8193 - val_loss: 0.5536 - val_accuracy: 0.8217
#
# Epoch 00031: val_loss improved from 0.56724 to 0.55360, saving model to models_1_2/31-0.82.h5
# Epoch 32/60
# 238/238 [==============================] - 628s 3s/step - loss: 0.5165 - accuracy: 0.8400 - val_loss: 0.6099 - val_accuracy: 0.8016
#
# Epoch 00032: val_loss did not improve from 0.55360
# Epoch 33/60
# 238/238 [==============================] - 623s 3s/step - loss: 0.5471 - accuracy: 0.8220 - val_loss: 0.5474 - val_accuracy: 0.8234
#
# Epoch 00033: val_loss improved from 0.55360 to 0.54744, saving model to models_1_2/33-0.82.h5
# Epoch 34/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.4990 - accuracy: 0.8436 - val_loss: 0.5425 - val_accuracy: 0.8223
#
# Epoch 00034: val_loss improved from 0.54744 to 0.54254, saving model to models_1_2/34-0.82.h5
# Epoch 35/60
# 238/238 [==============================] - 627s 3s/step - loss: 0.4909 - accuracy: 0.8502 - val_loss: 0.6676 - val_accuracy: 0.7877
#
# Epoch 00035: val_loss did not improve from 0.54254
# Epoch 36/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.4565 - accuracy: 0.8576 - val_loss: 0.5622 - val_accuracy: 0.8265
#
# Epoch 00036: val_loss did not improve from 0.54254
# Epoch 37/60
# 238/238 [==============================] - 624s 3s/step - loss: 0.4587 - accuracy: 0.8529 - val_loss: 0.5581 - val_accuracy: 0.8172
#
# Epoch 00037: val_loss did not improve from 0.54254
# Epoch 38/60
# 238/238 [==============================] - 620s 3s/step - loss: 0.4774 - accuracy: 0.8441 - val_loss: 0.5974 - val_accuracy: 0.8172
#
# Epoch 00038: val_loss did not improve from 0.54254
# Epoch 39/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.4499 - accuracy: 0.8578 - val_loss: 0.5338 - val_accuracy: 0.8278
#
# Epoch 00039: val_loss improved from 0.54254 to 0.53383, saving model to models_1_2/39-0.83.h5
# Epoch 40/60
# 238/238 [==============================] - 625s 3s/step - loss: 0.4281 - accuracy: 0.8679 - val_loss: 0.5542 - val_accuracy: 0.8295
#
# Epoch 00040: val_loss did not improve from 0.53383
# Epoch 41/60
# 238/238 [==============================] - 619s 3s/step - loss: 0.4252 - accuracy: 0.8667 - val_loss: 0.6157 - val_accuracy: 0.7885
#
# Epoch 00041: val_loss did not improve from 0.53383
# Epoch 42/60
# 238/238 [==============================] - 619s 3s/step - loss: 0.4143 - accuracy: 0.8744 - val_loss: 0.5337 - val_accuracy: 0.8225
#
# Epoch 00042: val_loss improved from 0.53383 to 0.53372, saving model to models_1_2/42-0.82.h5
# Epoch 43/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.4025 - accuracy: 0.8724 - val_loss: 0.5490 - val_accuracy: 0.8276
#
# Epoch 00043: val_loss did not improve from 0.53372
# Epoch 44/60
# 238/238 [==============================] - 622s 3s/step - loss: 0.3873 - accuracy: 0.8822 - val_loss: 0.6228 - val_accuracy: 0.8142
#
# Epoch 00044: val_loss did not improve from 0.53372
# Epoch 45/60
# 238/238 [==============================] - 617s 3s/step - loss: 0.3898 - accuracy: 0.8790 - val_loss: 0.5816 - val_accuracy: 0.8223
#
# Epoch 00045: val_loss did not improve from 0.53372
# Epoch 46/60
# 238/238 [==============================] - 618s 3s/step - loss: 0.3932 - accuracy: 0.8783 - val_loss: 0.5343 - val_accuracy: 0.8301
#
# Epoch 00046: val_loss did not improve from 0.53372
# Epoch 47/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.3805 - accuracy: 0.8840 - val_loss: 0.5495 - val_accuracy: 0.8309
#
# Epoch 00047: val_loss did not improve from 0.53372
# Epoch 48/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.3718 - accuracy: 0.8837 - val_loss: 0.5129 - val_accuracy: 0.8337
#
# Epoch 00048: val_loss improved from 0.53372 to 0.51294, saving model to models_1_2/48-0.83.h5
# Epoch 49/60
# 238/238 [==============================] - 623s 3s/step - loss: 0.3709 - accuracy: 0.8848 - val_loss: 0.5462 - val_accuracy: 0.8278
#
# Epoch 00049: val_loss did not improve from 0.51294
# Epoch 50/60
# 238/238 [==============================] - 620s 3s/step - loss: 0.3549 - accuracy: 0.8911 - val_loss: 0.5560 - val_accuracy: 0.8270
#
# Epoch 00050: val_loss did not improve from 0.51294
# Epoch 51/60
# 238/238 [==============================] - 619s 3s/step - loss: 0.3637 - accuracy: 0.8885 - val_loss: 0.6152 - val_accuracy: 0.8181
#
# Epoch 00051: val_loss did not improve from 0.51294
# Epoch 52/60
# 238/238 [==============================] - 618s 3s/step - loss: 0.3488 - accuracy: 0.8920 - val_loss: 0.5464 - val_accuracy: 0.8306
#
# Epoch 00052: val_loss did not improve from 0.51294
# Epoch 53/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.3349 - accuracy: 0.8980 - val_loss: 0.5758 - val_accuracy: 0.8318
#
# Epoch 00053: val_loss did not improve from 0.51294
# Epoch 54/60
# 238/238 [==============================] - 619s 3s/step - loss: 0.3364 - accuracy: 0.8977 - val_loss: 0.5383 - val_accuracy: 0.8407
#
# Epoch 00054: val_loss did not improve from 0.51294
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 55/60
# 238/238 [==============================] - 620s 3s/step - loss: 0.3082 - accuracy: 0.9113 - val_loss: 0.5291 - val_accuracy: 0.8465
#
# Epoch 00055: val_loss did not improve from 0.51294
# Epoch 56/60
# 238/238 [==============================] - 622s 3s/step - loss: 0.2813 - accuracy: 0.9205 - val_loss: 0.5257 - val_accuracy: 0.8454
#
# Epoch 00056: val_loss did not improve from 0.51294
# Epoch 57/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.2783 - accuracy: 0.9223 - val_loss: 0.5383 - val_accuracy: 0.8415
#
# Epoch 00057: val_loss did not improve from 0.51294
# Epoch 58/60
# 238/238 [==============================] - 620s 3s/step - loss: 0.2643 - accuracy: 0.9248 - val_loss: 0.5305 - val_accuracy: 0.8471
#
# Epoch 00058: val_loss did not improve from 0.51294
# Epoch 59/60
# 238/238 [==============================] - 622s 3s/step - loss: 0.2701 - accuracy: 0.9229 - val_loss: 0.5348 - val_accuracy: 0.8454
#
# Epoch 00059: val_loss did not improve from 0.51294
# Epoch 60/60
# 238/238 [==============================] - 621s 3s/step - loss: 0.2649 - accuracy: 0.9221 - val_loss: 0.5255 - val_accuracy: 0.8443
#
# Epoch 00060: val_loss did not improve from 0.51294
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.

# %% [markdown]
# Loss and Accuracy plot

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Model Evaluation

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 239/239 [==============================] - 159s 666ms/step - loss: 0.1845 - accuracy: 0.9622
# 57/57 [==============================] - 37s 642ms/step - loss: 0.5275 - accuracy: 0.8435
# final train accuracy = 96.22 , validation accuracy = 84.35

# %%
fernet.save_weights('model_bestweight_1_2.h5')

# %%
fernet.save('model_best_1_2.h5')

# %% [markdown]
# Confusion Matrix and Classification on training set

# %%
per = np.random.permutation(training_set.n)
training_set.index_array = per
classes = training_set.classes[per]

# %%
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[3636   46  178]
#  [  31 6592  101]
#  [  89  137 4423]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.97      0.94      0.95      3860
#        happy       0.97      0.98      0.98      6724
#      neutral       0.94      0.95      0.95      4649
#
#     accuracy                           0.96     15233
#    macro avg       0.96      0.96      0.96     15233
# weighted avg       0.96      0.96      0.96     15233

# %% [markdown]
# Confusion Matrix and Classification on test set

# %%
per = np.random.permutation(test_set.n)
test_set.index_array = per
classes = test_set.classes[per]

# %%
from keras.models import load_model
emotion_model_path = 'model_best_1_2.h5'
fernet = load_model(emotion_model_path)

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_test = confusion_matrix(classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[ 681   50  176]
#  [  72 1464   85]
#  [ 108   77  916]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.79      0.75      0.77       907
#        happy       0.92      0.90      0.91      1621
#      neutral       0.78      0.83      0.80      1101
#
#     accuracy                           0.84      3629
#    macro avg       0.83      0.83      0.83      3629
# weighted avg       0.84      0.84      0.84      3629

# %% [markdown]
# # 단일 사진 결과 확인

# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import cv2
import numpy as np
import sys
import time
#from google.colab.patches import cv2_imshow
 
# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
emotion_model_path = 'model_best_1_2.h5'
img_path =  "angry.jpg" # sys.argv[1]
 
# hyper-parameters for bounding boxes shape
# loading models
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ['angry', 'happy', 'neutral'] # , 'sad']
            
 
# reading the frame
orig_frame = cv2.imread(img_path)
#print(img_path)
#print(orig_frame)
frame = cv2.imread(img_path,0)
#print(frame)
faces = face_detection.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=5,minSize=(30,30),flags=cv2.CASCADE_SCALE_IMAGE)
 
if len(faces) > 0:
    print(faces)
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))[0]
    (fX, fY, fW, fH) = faces
    roi = frame[fY:fY + fH, fX:fX + fW]
    roi = cv2.resize(roi, (48, 48))
    roi = roi.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi, axis=0)
    preds = emotion_classifier.predict(roi)[0]
    emotion_probability = np.max(preds)
    label = EMOTIONS[preds.argmax()]
    cv2.putText(orig_frame, label, (fX, fY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
    cv2.rectangle(orig_frame, (fX, fY), (fX + fW, fY + fH),(0, 0, 255), 2)
 
cv2.imshow('test_face', orig_frame)
#cv2_imshow(orig_frame)
cv2.imwrite('test_output/'+img_path.split('/')[-1],orig_frame)
if (cv2.waitKey(0) and 0xFF == ord('q')):
    sys.exit("Thanks")
cv2.destroyAllWindows()

# %%
roi.shape

# %% [markdown]
# # 실시간 영상을 통한 결과 확인

# %%
from statistics import mode

import cv2
from keras.models import load_model
import numpy as np

from utils.datasets import get_labels
from utils.inference import detect_faces
from utils.inference import draw_text
from utils.inference import draw_bounding_box
from utils.inference import apply_offsets
from utils.inference import load_detection_model
from utils.preprocessor import preprocess_input

# parameters for loading data and images
detection_model_path = 'haarcascade_files/haarcascade_frontalface_default.xml'
#emotion_model_path = 'ferNet.h5'
emotion_model_path = 'model_best_1_2.h5'
emotion_labels = ['angry', 'happy', 'neutral'] # , 'sad']

# hyper-parameters for bounding boxes shape
frame_window = 10
emotion_offsets = (20, 40)

# loading models
face_detection = load_detection_model(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)

# getting input model shapes for inference
emotion_target_size = emotion_classifier.input_shape[1:3]

# starting lists for calculating modes
emotion_window = []

# %%
face_detection

# %%
emotion_labels

# %%
from keras.preprocessing.image import img_to_array

# starting video streaming
cv2.namedWindow('window_frame')
video_capture = cv2.VideoCapture(0)
while True:
    bgr_image = video_capture.read()[1]
    gray_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2GRAY)
    rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
    faces = detect_faces(face_detection, gray_image)
    
    for face_coordinates in faces:

        x1, x2, y1, y2 = apply_offsets(face_coordinates, emotion_offsets)
        gray_face = gray_image[y1:y2, x1:x2]
        try:
            gray_face = cv2.resize(gray_face, (emotion_target_size))
        except:
            continue

        gray_face = preprocess_input(gray_face, True)
        gray_face = np.expand_dims(gray_face, 0)
        gray_face = np.expand_dims(gray_face, -1)
        emotion_prediction = emotion_classifier.predict(gray_face)
        emotion_probability = np.max(emotion_prediction)
        emotion_label_arg = np.argmax(emotion_prediction)
        emotion_text = emotion_labels[emotion_label_arg]
        emotion_window.append(emotion_text)

        if len(emotion_window) > frame_window:
            emotion_window.pop(0)
        try:
            emotion_mode = mode(emotion_window)
        except:
            continue

        if emotion_text == 'angry':
            color = emotion_probability * np.asarray((255, 0, 0))
        elif emotion_text == 'happy':
            color = emotion_probability * np.asarray((0, 0, 255))
        elif emotion_text == 'neutral':
            color = emotion_probability * np.asarray((255, 255, 0))
        elif emotion_text == 'sad':
            color = emotion_probability * np.asarray((0, 255, 255))
        else:
            color = emotion_probability * np.asarray((0, 255, 0))

        color = color.astype(int)
        color = color.tolist()

        draw_bounding_box(face_coordinates, rgb_image, color)
        draw_text(face_coordinates, rgb_image, emotion_mode,
                  color, 0, -45, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[0])+' : '+str(round(emotion_prediction[0][0],2)),
                  [0, 99, 99], 250, 10, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[1])+' : '+str(round(emotion_prediction[0][1],2)),
                  [99, 0, 99], 250, 60, 1, 1)
        draw_text(face_coordinates, rgb_image, str(emotion_labels[2])+' : '+str(round(emotion_prediction[0][2],2)),
                  [0, 99, 0], 250, 110, 1, 1)
        #draw_text(face_coordinates, rgb_image, str(emotion_labels[3])+' : '+str(round(emotion_prediction[0][3],2)),
        #          [0, 0, 0], 250, 160, 1, 1)
        
        
        
    bgr_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2BGR)
    cv2.imshow('window_frame', bgr_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()

# %%
emotion_prediction
